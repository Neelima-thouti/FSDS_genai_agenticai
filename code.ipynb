# %%
pip install pandas seaborn matplotlib gradio ollama
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: gradio in c:\users\hp\appdata\local\anaconda3\lib\site-packages (5.37.0)
# Collecting ollama
#   Using cached ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.6.0)
# Requirement already satisfied: gradio-client==1.10.4 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (1.10.4)
# Requirement already satisfied: groovy~=0.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.33.4)
# Requirement already satisfied: jinja2<4.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.47.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio-client==1.10.4->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from gradio-client==1.10.4->gradio) (15.0.1)
# Collecting pydantic<2.12,>=2.0 (from gradio)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio)
#   Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-extensions~=4.0 (from gradio)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Using cached ollama-0.5.1-py3-none-any.whl (13 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.7 MB/s eta 0:00:00
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-extensions, typing-inspection, pydantic-core, pydantic, ollama
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed ollama-0.5.1 pydantic-2.11.7 pydantic-core-2.33.2 typing-extensions-4.14.1 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = r"C:\Users\hp\Downloads\titanic_ dataset_final.csv"
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import ollama
def generate_insights(df_summary):
    prompt=f"Analyze the dataset summary and provide insights:\n\n{df_summary}"
    response=ollama.chat(model="mistral",messages=[{"role":"user","content":prompt}])
    return response['message'],['content']
summary=df.describe().to_string()
insights=generate_insights(summary)
print("\n🔹 AI-Generated Insights:\n", insights)
# Out:
# 🔹 AI-Generated Insights:
#  (Message(role='assistant', content=" The dataset is a portion of the Titanic passenger list, containing 891 records. Here's an analysis of the variables:\n\n1. **PassengerId**: This column contains unique identifiers for each passenger, ranging from 1 to 891.\n\n2. **Survived**: This binary variable (0 or 1) indicates whether a passenger survived the Titanic disaster or not. The mean value is approximately 0.38, suggesting that slightly more than one-third of passengers survived.\n\n3. **Pclass**: This categorical variable represents the class of travel, with three levels: First (1), Second (2), and Third (3). The mean value of 2.3 indicates that a majority of passengers were traveling in second class, as this is the mode (most frequent) value.\n\n4. **Age**: This continuous variable provides the age of each passenger. The mean age is around 29 years, with a standard deviation of about 14.5 years, indicating a wide range of ages among passengers.\n\n5. **SibSp (Siblings and Spouses)**: This integer variable indicates the number of siblings and spouses aboard the ship along with the passenger. The mean value is approximately 0.52, suggesting that each passenger had slightly more than half a sibling or spouse on board.\n\n6. **Parch (Parents and Children)**: This integer variable provides the number of parents and children accompanying the passenger. The mean value is around 0.38, indicating that each passenger had approximately one parent or child on board.\n\n7. **Fare**: This continuous variable represents the ticket fare paid by the passenger to travel. The mean fare is around $32, with a standard deviation of about $50, suggesting substantial variation in ticket prices. The minimum fare is $0, and the maximum is $512.33.", thinking=None, images=None, tool_calls=None), ['content'])

# %%
import gradio as gr

def eda_analysis(file):
    df = pd.read_csv(file.name)
    summary = df.describe().to_string()
    insights = generate_insights(summary)
    return insights

# Create Web Interface
demo = gr.Interface(fn=eda_analysis, inputs="file", outputs="text", title="AI-Powered EDA with Mistral")

# Launch App
demo.launch(share=True)  # Use share=True for Google Colab
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://879910c211a02d625a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://879910c211a02d625a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio\flagged\dataset1.csv
